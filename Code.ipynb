# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.io as pio
#For Preprocessing
import re    # RegEx for removing non-letter characters

pio.renderers.default = 'png'


# For Preprocessing
import re  # RegEx for removing non-letter characters
import nltk  #natural language processing
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *

# For Building the model
from sklearn.model_selection import train_test_split
import tensorflow as tf
import seaborn as sns

# For data visualization
import matplotlib.pyplot as plt

pd.options.plotting.backend = "plotly"

# load all_twitter dataset
data1 = pd.read_csv("/content/amazon_alexa_data.csv")
data1 = pd.DataFrame(data1)

# Load Tweet dataset
data1.isnull()
# data1.dropna(axis=0, inplace=True)

print(data1.head())

print(data1.columns)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0  Despite the fact that I have only played a sma...         1
# 1  I bought this charger in Jul 1003 and it worke...         0
# 2  Check out Maha Energy's website. Their Powerex...         1
# 3  Reviewed quite a bit of the combo players and ...         1
# 4  I also began having the incorrect disc problem...         0
# Index(['rating', 'date', 'variation', 'verified_reviews', 'feedback'], dtype='object')

# %% [markdown]
# # EDA and Analysis

# %%
df = data1

print(df.head(10))
print("\n\nDataset Desciption: ")
print(df.describe())
print("\n\nDataset Info: ")
print(df.info())

print(df.shape)

print("\n\nNull Values Count",df.isnull().sum())
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0  Despite the fact that I have only played a sma...         1
# 1  I bought this charger in Jul 1003 and it worke...         0
# 2  Check out Maha Energy's website. Their Powerex...         1
# 3  Reviewed quite a bit of the combo players and ...         1
# 4  I also began having the incorrect disc problem...         0
# 5  I love the style of this, but after a couple y...         0
# 6  I cannot scroll through a DVD menu that is set...         0
# 7  Exotic tales of the Orient from the 0930's. "D...         1
# 8  Firstly,I enjoyed the format and tone of the b...         0
# 9  I currently live in Europe, and this is the bo...         1
#
#
# Dataset Desciption:
#             rating     feedback
# count  6300.000000  6300.000000
# mean      4.463175     0.513968
# std       1.068421     0.499845
# min       1.000000     0.000000
# 25%       4.000000     0.000000
# 50%       5.000000     1.000000
# 75%       5.000000     1.000000
# max       5.000000     1.000000
#
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6300 entries, 0 to 6299
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rating            6300 non-null   int64
#  1   date              6300 non-null   object
#  2   variation         6300 non-null   object
#  3   verified_reviews  6300 non-null   object
#  4   feedback          6300 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 246.2+ KB
# None
# (6300, 5)
#
#
# Null Values Count rating              0
# date                0
# variation           0
# verified_reviews    0
# feedback            0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Plot pair plots for selected columns
sns.pairplot(df, diag_kind='kde')
plt.show()

# %%
# Summary of key insights
summary = {
    'total_rows': df.shape[0],
    'total_columns': df.shape[1],
    'missing_values': df.isnull().sum().to_dict(),
    'data_types': df.dtypes.to_dict(),
    'statistical_summary': df.describe().to_dict()
}
print(summary)
# Out:
# {'total_rows': 6300, 'total_columns': 5, 'missing_values': {'rating': 0, 'date': 0, 'variation': 0, 'verified_reviews': 0, 'feedback': 0}, 'data_types': {'rating': dtype('int64'), 'date': dtype('O'), 'variation': dtype('O'), 'verified_reviews': dtype('O'), 'feedback': dtype('int64')}, 'statistical_summary': {'rating': {'count': 6300.0, 'mean': 4.463174603174603, 'std': 1.0684210298627346, 'min': 1.0, '25%': 4.0, '50%': 5.0, '75%': 5.0, 'max': 5.0}, 'feedback': {'count': 6300.0, 'mean': 0.513968253968254, 'std': 0.4998445215719408, 'min': 0.0, '25%': 0.0, '50%': 1.0, '75%': 1.0, 'max': 1.0}}}

# %%
from wordcloud import WordCloud, STOPWORDS

def wordcount_gen(df, feedback):

    # Combine all tweets
    combined_text = " ".join([i for i in df[df.feedback==feedback]['verified_reviews']])

    # Initialize wordcloud object
    wc = WordCloud(background_color='white',
                   max_words=40,
                   stopwords = STOPWORDS)

    # Generate and plot wordcloud
    if feedback==1:
        plt.figure(figsize=(10,10))
        plt.imshow(wc.generate(combined_text))
        feedback = "Positive"
        plt.title('{} Sentiment Words'.format(feedback), fontsize=20)
        plt.axis('off')
        plt.show()
    else:
        plt.figure(figsize=(10,10))
        plt.imshow(wc.generate(combined_text))
        feedback = "Negative"
        plt.title('{} Sentiment Words'.format(feedback), fontsize=20)
        plt.axis('off')
        plt.show()


# Positive tweet words
wordcount_gen(df,1)

# Negative tweet words
wordcount_gen(df,0)

# %%
def text_to_words(tweet):
    ''' Convert tweet text into a sequence of words '''

    text = tweet.lower()
    # remove non letters
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)
    words = text.split()
    words = [w for w in words if w not in stopwords.words("english")]
    words = [PorterStemmer().stem(w) for w in words]
    return words

print("\nOriginal text ->", df['verified_reviews'][0])
print("\nProcessed text ->", text_to_words(df['verified_reviews'][0]))
# Out:
# Original text -> Despite the fact that I have only played a small portion of the game, the music I heard (plus the connection to Chrono Trigger which was great as well) led me to purchase the soundtrack, and it remains one of my favorite albums. There is an incredible mix of fun, epic, and emotional songs. Those sad and beautiful tracks I especially like, as there's not too many of those kinds of songs in my other video game soundtracks. I must admit that one of the songs (Life-A Distant Promise) has brought tears to my eyes on many occasions.My one complaint about this soundtrack is that they use guitar fretting effects in many of the songs, which I find distracting. But even if those weren't included I would still consider the collection worth it.
#
# Processed text -> ['despit', 'fact', 'play', 'small', 'portion', 'game', 'music', 'heard', 'plu', 'connect', 'chrono', 'trigger', 'great', 'well', 'led', 'purchas', 'soundtrack', 'remain', 'one', 'favorit', 'album', 'incred', 'mix', 'fun', 'epic', 'emot', 'song', 'sad', 'beauti', 'track', 'especi', 'like', 'mani', 'kind', 'song', 'video', 'game', 'soundtrack', 'must', 'admit', 'one', 'song', 'life', 'distant', 'promis', 'brought', 'tear', 'eye', 'mani', 'occas', 'one', 'complaint', 'soundtrack', 'use', 'guitar', 'fret', 'effect', 'mani', 'song', 'find', 'distract', 'even', 'includ', 'would', 'still', 'consid', 'collect', 'worth']

# %%
# Apply data processing to each tweet
x = list(map(text_to_words, df['verified_reviews']))
from sklearn.preprocessing import LabelEncoder

# Encode target labels
y = pd.get_dummies(df['verified_reviews'])
print(x[0])
# Out:
# ['despit', 'fact', 'play', 'small', 'portion', 'game', 'music', 'heard', 'plu', 'connect', 'chrono', 'trigger', 'great', 'well', 'led', 'purchas', 'soundtrack', 'remain', 'one', 'favorit', 'album', 'incred', 'mix', 'fun', 'epic', 'emot', 'song', 'sad', 'beauti', 'track', 'especi', 'like', 'mani', 'kind', 'song', 'video', 'game', 'soundtrack', 'must', 'admit', 'one', 'song', 'life', 'distant', 'promis', 'brought', 'tear', 'eye', 'mani', 'occas', 'one', 'complaint', 'soundtrack', 'use', 'guitar', 'fret', 'effect', 'mani', 'song', 'find', 'distract', 'even', 'includ', 'would', 'still', 'consid', 'collect', 'worth']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.70,test_size=0.30, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.70,test_size=0.30, random_state=1)

from sklearn.feature_extraction.text import CountVectorizer
#from sklearn.feature_extraction.text import TfidfVectorizer

vocabulary_size = 5000

# Tweets have already been preprocessed hence dummy function will be passed in
# to preprocessor & tokenizer step
count_vector = CountVectorizer(max_features=vocabulary_size,
#                               ngram_range=(1,2),    # unigram and bigram
                                preprocessor=lambda x: x,
                               tokenizer=lambda x: x)
#tfidf_vector = TfidfVectorizer(lowercase=True, stop_words='english')

# Fit the training data
X_train = count_vector.fit_transform(X_train).toarray()

# Transform testing data
X_test = count_vector.transform(X_test).toarray()
#import sklearn.preprocessing as pr

# Normalize BoW features in training and test set
#X_train = pr.normalize(X_train, axis=1)
#X_test  = pr.normalize(X_test, axis=1)
# print first 200 words/tokens
print(count_vector.get_feature_names_out()[0:200])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:525: UserWarning:
#
# The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
# ['0' '00' '000' '0000' '00000' '0080p' '00th' '01' '03' '0367' '0369' '04'
#  '05' '06' '060' '0600' '07' '08' '08th' '09' '091' '0930' '0940' '0948'
#  '0950' '0954' '0963' '0964' '0968' '0970' '0973' '0979' '0980' '0984'
#  '0985' '0988' '0990' '0991' '0993' '0994' '0996' '09th' '0st' '1' '10'
#  '100' '1000' '1001' '1003' '1005' '1006' '1007' '1008' '1009' '10st'
#  '10th' '11' '13' '14' '15' '150' '16' '17' '1nd' '3' '30' '300' '33' '35'
#  '36' '360' '3d' '3rd' '4' '40' '400' '41' '45' '450' '48' '4th' '5' '50'
#  '500' '6' '60' '670' '6th' '7' '70' '700' '75' '7th' '8' '80' '85' '88'
#  '9' '90' '94' '95' '98' '99' '9th' 'aa' 'abel' 'abil' 'abl' 'abound'
#  'abraham' 'abridg' 'absolut' 'absorb' 'absurd' 'abus' 'ac' 'academ'
#  'academi' 'accept' 'access' 'accessori' 'accid' 'accident' 'accompani'
#  'accomplish' 'accord' 'account' 'accur' 'accuraci' 'accus' 'ace' 'ach'
#  'achiev' 'ackroyd' 'acoust' 'across' 'act' 'action' 'activ' 'actor'
#  'actress' 'actual' 'ad' 'adam' 'adapt' 'adaptor' 'add' 'adder' 'addict'
#  'addit' 'address' 'adequ' 'adjust' 'admir' 'admiss' 'admit' 'adob'
#  'adolesc' 'adopt' 'ador' 'adult' 'adulteri' 'advanc' 'advantag'
#  'adventur' 'advertis' 'advic' 'advis' 'aesthet' 'affair' 'affect'
#  'afford' 'afraid' 'africa' 'african' 'afternoon' 'afterward' 'age'
#  'agent' 'agey' 'ago' 'agre' 'ah' 'ahead' 'ai' 'aid' 'aiken' 'aim' 'air'
#  'airb' 'airlift' 'airplan' 'al' 'ala' 'alan' 'alarm' 'albeit' 'albert'
#  'album' 'alex']

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

max_words = 5000
max_len=50

def tokenize_pad_sequences(text):
    '''
    This function tokenize the input text into sequnences of intergers and then
    pad each sequence to the same length
    '''
    # Text tokenization
    tokenizer = Tokenizer(num_words=max_words, lower=True, split=' ')
    tokenizer.fit_on_texts(text)
    # Transforms text to a sequence of integers
    X = tokenizer.texts_to_sequences(text)
    # Pad sequences to the same length
    X = pad_sequences(X, padding='post', maxlen=max_len)
    # return sequences
    return X, tokenizer

print('Before Tokenization & Padding \n', df['verified_reviews'][0])
X, tokenizer = tokenize_pad_sequences(df['verified_reviews'])
print('After Tokenization & Padding \n', x[0])

import pickle

# saving
with open('tokenizer1.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('tokenizer1.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

y = pd.get_dummies(df['feedback'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state=1)
print('Train Set ->', X_train.shape, y_train.shape)
print('Validation Set ->', X_val.shape, y_val.shape)
print('Test Set ->', X_test.shape, y_test.shape)
# Out:
# Before Tokenization & Padding
#  Despite the fact that I have only played a small portion of the game, the music I heard (plus the connection to Chrono Trigger which was great as well) led me to purchase the soundtrack, and it remains one of my favorite albums. There is an incredible mix of fun, epic, and emotional songs. Those sad and beautiful tracks I especially like, as there's not too many of those kinds of songs in my other video game soundtracks. I must admit that one of the songs (Life-A Distant Promise) has brought tears to my eyes on many occasions.My one complaint about this soundtrack is that they use guitar fretting effects in many of the songs, which I find distracting. But even if those weren't included I would still consider the collection worth it.
# After Tokenization & Padding
#  ['despit', 'fact', 'play', 'small', 'portion', 'game', 'music', 'heard', 'plu', 'connect', 'chrono', 'trigger', 'great', 'well', 'led', 'purchas', 'soundtrack', 'remain', 'one', 'favorit', 'album', 'incred', 'mix', 'fun', 'epic', 'emot', 'song', 'sad', 'beauti', 'track', 'especi', 'like', 'mani', 'kind', 'song', 'video', 'game', 'soundtrack', 'must', 'admit', 'one', 'song', 'life', 'distant', 'promis', 'brought', 'tear', 'eye', 'mani', 'occas', 'one', 'complaint', 'soundtrack', 'use', 'guitar', 'fret', 'effect', 'mani', 'song', 'find', 'distract', 'even', 'includ', 'would', 'still', 'consid', 'collect', 'worth']
# Train Set -> (3087, 50) (3087, 2)
# Validation Set -> (1323, 50) (1323, 2)
# Test Set -> (1890, 50) (1890, 2)

# %% [markdown]
# # Bidirectional LSTM

# %%
import keras.backend as K


def f1_score(precision, recall):
    ''' Function to calculate f1 score '''

    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout,Flatten,RNN
from keras.metrics import Precision, Recall

from keras.optimizers.legacy import SGD
from keras.optimizers import RMSprop
from keras import datasets

from keras.callbacks import LearningRateScheduler
from keras.callbacks import History

from keras import losses

vocab_size = 5000
embedding_size = 32
epochs=50
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8

sgd = SGD(learning_rate=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
# Build model
model= Sequential()
model.add(Embedding(vocab_size, embedding_size, input_length=max_len))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=4))
model.add(Bidirectional(LSTM(32)))
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(2, activation='softmax'))
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)
plt.show()
print(model.summary())

# Compile model
model.compile(loss='categorical_crossentropy', optimizer=sgd,
               metrics=['accuracy', Precision(), Recall()])

# Train model

batch_size = 64
history = model.fit(X_train, y_train,
                      validation_data=(X_val, y_val),
                      batch_size=batch_size, epochs=epochs, verbose=1)

# Evaluate model on the test set
loss, bilstm_accuracy, precision, recall = model.evaluate(X_test, y_test, verbose=0)
# Print metrics
print('')
print('Accuracy  : {:.4f}'.format(bilstm_accuracy))
print('Precision : {:.4f}'.format(precision))
print('Recall    : {:.4f}'.format(recall))
print('F1 Score  : {:.4f}'.format(f1_score(precision, recall)))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 32)            160000
#
#  conv1d (Conv1D)             (None, 50, 32)            3104
#
#  max_pooling1d (MaxPooling1  (None, 12, 32)            0
#  D)
#
#  bidirectional (Bidirection  (None, 64)                16640
#  al)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 179874 (702.63 KB)
# Trainable params: 179874 (702.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 49/49 [==============================] - 6s 41ms/step - loss: 0.6928 - accuracy: 0.5258 - precision: 0.5258 - recall: 0.5258 - val_loss: 0.6964 - val_accuracy: 0.5147 - val_precision: 0.5147 - val_recall: 0.5147
# Epoch 2/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6908 - accuracy: 0.5296 - precision: 0.5296 - recall: 0.5296 - val_loss: 0.6898 - val_accuracy: 0.5185 - val_precision: 0.5185 - val_recall: 0.5185
# Epoch 3/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.6891 - accuracy: 0.5261 - precision: 0.5261 - recall: 0.5261 - val_loss: 0.6901 - val_accuracy: 0.5231 - val_precision: 0.5231 - val_recall: 0.5231
# Epoch 4/50
# 49/49 [==============================] - 1s 22ms/step - loss: 0.6862 - accuracy: 0.5520 - precision: 0.5520 - recall: 0.5520 - val_loss: 0.6905 - val_accuracy: 0.5314 - val_precision: 0.5314 - val_recall: 0.5314
# Epoch 5/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.6826 - accuracy: 0.5637 - precision: 0.5637 - recall: 0.5637 - val_loss: 0.6853 - val_accuracy: 0.5624 - val_precision: 0.5624 - val_recall: 0.5624
# Epoch 6/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.6785 - accuracy: 0.5594 - precision: 0.5594 - recall: 0.5594 - val_loss: 0.6822 - val_accuracy: 0.5321 - val_precision: 0.5321 - val_recall: 0.5321
# Epoch 7/50
# 49/49 [==============================] - 1s 21ms/step - loss: 0.6674 - accuracy: 0.5928 - precision: 0.5928 - recall: 0.5928 - val_loss: 0.6889 - val_accuracy: 0.5465 - val_precision: 0.5465 - val_recall: 0.5465
# Epoch 8/50
# 49/49 [==============================] - 1s 20ms/step - loss: 0.6480 - accuracy: 0.6246 - precision: 0.6246 - recall: 0.6246 - val_loss: 0.6396 - val_accuracy: 0.6402 - val_precision: 0.6402 - val_recall: 0.6402
# Epoch 9/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6135 - accuracy: 0.6644 - precision: 0.6644 - recall: 0.6644 - val_loss: 0.6731 - val_accuracy: 0.5926 - val_precision: 0.5926 - val_recall: 0.5926
# Epoch 10/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.5953 - accuracy: 0.6774 - precision: 0.6774 - recall: 0.6774 - val_loss: 0.6007 - val_accuracy: 0.6765 - val_precision: 0.6765 - val_recall: 0.6765
# Epoch 11/50
# 49/49 [==============================] - 1s 17ms/step - loss: 0.5602 - accuracy: 0.7120 - precision: 0.7120 - recall: 0.7120 - val_loss: 0.5723 - val_accuracy: 0.6969 - val_precision: 0.6969 - val_recall: 0.6969
# Epoch 12/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.5296 - accuracy: 0.7340 - precision: 0.7340 - recall: 0.7340 - val_loss: 0.5746 - val_accuracy: 0.6893 - val_precision: 0.6893 - val_recall: 0.6893
# Epoch 13/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.4632 - accuracy: 0.7920 - precision: 0.7920 - recall: 0.7920 - val_loss: 0.5261 - val_accuracy: 0.7332 - val_precision: 0.7332 - val_recall: 0.7332
# Epoch 14/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.4577 - accuracy: 0.7937 - precision: 0.7937 - recall: 0.7937 - val_loss: 0.5237 - val_accuracy: 0.7362 - val_precision: 0.7362 - val_recall: 0.7362
# Epoch 15/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.3883 - accuracy: 0.8238 - precision: 0.8238 - recall: 0.8238 - val_loss: 0.5400 - val_accuracy: 0.7415 - val_precision: 0.7415 - val_recall: 0.7415
# Epoch 16/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.3760 - accuracy: 0.8332 - precision: 0.8332 - recall: 0.8332 - val_loss: 0.6722 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992
# Epoch 17/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.3696 - accuracy: 0.8426 - precision: 0.8426 - recall: 0.8426 - val_loss: 0.5840 - val_accuracy: 0.7415 - val_precision: 0.7415 - val_recall: 0.7415
# Epoch 18/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.2871 - accuracy: 0.8814 - precision: 0.8814 - recall: 0.8814 - val_loss: 0.5726 - val_accuracy: 0.7521 - val_precision: 0.7521 - val_recall: 0.7521
# Epoch 19/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.2856 - accuracy: 0.8776 - precision: 0.8776 - recall: 0.8776 - val_loss: 0.5603 - val_accuracy: 0.7521 - val_precision: 0.7521 - val_recall: 0.7521
# Epoch 20/50
# 49/49 [==============================] - 1s 21ms/step - loss: 0.2124 - accuracy: 0.9180 - precision: 0.9180 - recall: 0.9180 - val_loss: 0.6123 - val_accuracy: 0.7642 - val_precision: 0.7642 - val_recall: 0.7642
# Epoch 21/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.1838 - accuracy: 0.9278 - precision: 0.9278 - recall: 0.9278 - val_loss: 0.7654 - val_accuracy: 0.7332 - val_precision: 0.7332 - val_recall: 0.7332
# Epoch 22/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1819 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - val_loss: 0.7448 - val_accuracy: 0.7543 - val_precision: 0.7543 - val_recall: 0.7543
# Epoch 23/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1945 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - val_loss: 0.6547 - val_accuracy: 0.7559 - val_precision: 0.7559 - val_recall: 0.7559
# Epoch 24/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1113 - accuracy: 0.9615 - precision: 0.9615 - recall: 0.9615 - val_loss: 0.9234 - val_accuracy: 0.7453 - val_precision: 0.7453 - val_recall: 0.7453
# Epoch 25/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.2383 - accuracy: 0.9086 - precision: 0.9086 - recall: 0.9086 - val_loss: 0.9941 - val_accuracy: 0.7045 - val_precision: 0.7045 - val_recall: 0.7045
# Epoch 26/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0954 - accuracy: 0.9692 - precision: 0.9692 - recall: 0.9692 - val_loss: 0.8790 - val_accuracy: 0.7551 - val_precision: 0.7551 - val_recall: 0.7551
# Epoch 27/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0437 - accuracy: 0.9896 - precision: 0.9896 - recall: 0.9896 - val_loss: 0.9760 - val_accuracy: 0.7604 - val_precision: 0.7604 - val_recall: 0.7604
# Epoch 28/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0351 - accuracy: 0.9896 - precision: 0.9896 - recall: 0.9896 - val_loss: 1.0518 - val_accuracy: 0.7528 - val_precision: 0.7528 - val_recall: 0.7528
# Epoch 29/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0182 - accuracy: 0.9977 - precision: 0.9977 - recall: 0.9977 - val_loss: 1.0941 - val_accuracy: 0.7589 - val_precision: 0.7589 - val_recall: 0.7589
# Epoch 30/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1315 - accuracy: 0.9498 - precision: 0.9498 - recall: 0.9498 - val_loss: 0.8840 - val_accuracy: 0.7370 - val_precision: 0.7370 - val_recall: 0.7370
# Epoch 31/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0551 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - val_loss: 1.0034 - val_accuracy: 0.7672 - val_precision: 0.7672 - val_recall: 0.7672
# Epoch 32/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0131 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - val_loss: 1.1176 - val_accuracy: 0.7566 - val_precision: 0.7566 - val_recall: 0.7566
# Epoch 33/50
# 49/49 [==============================] - 1s 22ms/step - loss: 0.0150 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - val_loss: 1.1879 - val_accuracy: 0.7611 - val_precision: 0.7611 - val_recall: 0.7611
# Epoch 34/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0051 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2070 - val_accuracy: 0.7627 - val_precision: 0.7627 - val_recall: 0.7627
# Epoch 35/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0038 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2427 - val_accuracy: 0.7627 - val_precision: 0.7627 - val_recall: 0.7627
# Epoch 36/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0029 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2604 - val_accuracy: 0.7619 - val_precision: 0.7619 - val_recall: 0.7619
# Epoch 37/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0025 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2815 - val_accuracy: 0.7634 - val_precision: 0.7634 - val_recall: 0.7634
# Epoch 38/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0023 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3039 - val_accuracy: 0.7649 - val_precision: 0.7649 - val_recall: 0.7649
# Epoch 39/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0020 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3175 - val_accuracy: 0.7619 - val_precision: 0.7619 - val_recall: 0.7619
# Epoch 40/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0019 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3357 - val_accuracy: 0.7634 - val_precision: 0.7634 - val_recall: 0.7634
# Epoch 41/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3468 - val_accuracy: 0.7611 - val_precision: 0.7611 - val_recall: 0.7611
# Epoch 42/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3710 - val_accuracy: 0.7611 - val_precision: 0.7611 - val_recall: 0.7611
# Epoch 43/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3752 - val_accuracy: 0.7611 - val_precision: 0.7611 - val_recall: 0.7611
# Epoch 44/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0016 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3848 - val_accuracy: 0.7611 - val_precision: 0.7611 - val_recall: 0.7611
# Epoch 45/50
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0014 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3902 - val_accuracy: 0.7581 - val_precision: 0.7581 - val_recall: 0.7581
# Epoch 46/50
# 49/49 [==============================] - 1s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4046 - val_accuracy: 0.7596 - val_precision: 0.7596 - val_recall: 0.7596
# Epoch 47/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4114 - val_accuracy: 0.7611 - val_precision: 0.7611 - val_recall: 0.7611
# Epoch 48/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4200 - val_accuracy: 0.7596 - val_precision: 0.7596 - val_recall: 0.7596
# Epoch 49/50
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0013 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4278 - val_accuracy: 0.7589 - val_precision: 0.7589 - val_recall: 0.7589
# Epoch 50/50
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4348 - val_accuracy: 0.7596 - val_precision: 0.7596 - val_recall: 0.7596
#
# Accuracy  : 0.7698
# Precision : 0.7698
# Recall    : 0.7698
# F1 Score  : 0.7698

# %%
def plot_training_hist(history):
    '''Function to plot history for accuracy and loss'''

    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    # first plot
    ax[0].plot(history.history['accuracy'])
    ax[0].plot(history.history['val_accuracy'])
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('epoch')
    ax[0].set_ylabel('accuracy')
    ax[0].legend(['train', 'validation'], loc='best')
    # second plot
    ax[1].plot(history.history['loss'])
    ax[1].plot(history.history['val_loss'])
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('epoch')
    ax[1].set_ylabel('loss')
    ax[1].legend(['train', 'validation'], loc='best')


plot_training_hist(history)

# %%
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(model, X_test, y_test):
    '''Function to plot confusion matrix for the passed model and the data'''

    sentiment_classes = ['Negative', 'Neutral', 'Positive']
    # use model to do the prediction
    y_pred = model.predict(X_test)
    # compute confusion matrix
    cm = confusion_matrix(np.argmax(np.array(y_test), axis=1), np.argmax(y_pred, axis=1))
    # plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='d',
                xticklabels=sentiment_classes,
                yticklabels=sentiment_classes)
    plt.title('Confusion matrix', fontsize=16)
    plt.xlabel('Actual label', fontsize=12)
    plt.ylabel('Predicted label', fontsize=12)


plot_confusion_matrix(model, X_test, y_test)

# Save the model architecture & the weights
model.save('bilstm_model.h5')
print('Best model saved')
# Out:
# 60/60 [==============================] - 1s 4ms/step
# Best model saved
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.

# %%
from keras.models import load_model

# Load model
model = load_model('bilstm_model.h5')


def predict_class(text):
    '''Function to predict sentiment class of the passed text'''

    sentiment_classes = ['Negative', 'Positive']
    max_len = 50

    # Transforms text to a sequence of integers using a tokenizer object
    xt = tokenizer.texts_to_sequences(text)
    # Pad sequences to the same length
    xt = pad_sequences(xt, padding='post', maxlen=max_len)
    # Do the prediction using the loaded model
    yt = model.predict(xt).argmax(axis=1)
    print(yt)
    # Print the predicted sentiment
    print('The predicted sentiment is', sentiment_classes[yt[0]])


predict_class(['the worst purchase ever i did, stopped working in few days '])

predict_class(['A Nice product'])

predict_class(['Awsome product to use and very satisfied and like'])
# Out:
# 1/1 [==============================] - 1s 810ms/step
# [0]
# The predicted sentiment is Negative
# 1/1 [==============================] - 0s 22ms/step
# [1]
# The predicted sentiment is Positive
# 1/1 [==============================] - 0s 22ms/step
# [1]
# The predicted sentiment is Positive

# %% [markdown]
# # RNN

# %%
import keras.backend as K


def f1_score(precision, recall):
    ''' Function to calculate f1 score '''

    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout,Flatten,SimpleRNN
from keras.metrics import Precision, Recall
from keras.optimizers.legacy import SGD
from keras.optimizers import RMSprop
from keras import datasets

from keras.callbacks import LearningRateScheduler
from keras.callbacks import History

from keras import losses

vocab_size = 5000
embedding_size = 32
epochs=25
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8

sgd = SGD(learning_rate=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
# Build model
model= Sequential()
model.add(Embedding(vocab_size, embedding_size, input_length=max_len))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=4))
model.add(SimpleRNN(12))
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(2, activation='softmax'))
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)
plt.show()
print(model.summary())

# Compile model
model.compile(loss='categorical_crossentropy', optimizer=sgd,
               metrics=['accuracy', Precision(), Recall()])

# Train model

batch_size = 64
history = model.fit(X_train, y_train,
                      validation_data=(X_val, y_val),
                      batch_size=batch_size, epochs=epochs, verbose=1)

# Evaluate model on the test set
loss, rnn_accuracy, precision, recall = model.evaluate(X_test, y_test, verbose=0)
# Print metrics
print('')
print('Accuracy  : {:.4f}'.format(rnn_accuracy))
print('Precision : {:.4f}'.format(precision))
print('Recall    : {:.4f}'.format(recall))
print('F1 Score  : {:.4f}'.format(f1_score(precision, recall)))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 50, 32)            160000
#
#  conv1d_1 (Conv1D)           (None, 50, 32)            3104
#
#  max_pooling1d_1 (MaxPoolin  (None, 12, 32)            0
#  g1D)
#
#  simple_rnn (SimpleRNN)      (None, 12)                540
#
#  flatten_1 (Flatten)         (None, 12)                0
#
#  dropout_1 (Dropout)         (None, 12)                0
#
#  dense_1 (Dense)             (None, 2)                 26
#
# =================================================================
# Total params: 163670 (639.34 KB)
# Trainable params: 163670 (639.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 49/49 [==============================] - 4s 19ms/step - loss: 0.7005 - accuracy: 0.5303 - precision_1: 0.5303 - recall_1: 0.5303 - val_loss: 0.6937 - val_accuracy: 0.5026 - val_precision_1: 0.5026 - val_recall_1: 0.5026
# Epoch 2/25
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6824 - accuracy: 0.5611 - precision_1: 0.5611 - recall_1: 0.5611 - val_loss: 0.6929 - val_accuracy: 0.5117 - val_precision_1: 0.5117 - val_recall_1: 0.5117
# Epoch 3/25
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6637 - accuracy: 0.6058 - precision_1: 0.6058 - recall_1: 0.6058 - val_loss: 0.7109 - val_accuracy: 0.4913 - val_precision_1: 0.4913 - val_recall_1: 0.4913
# Epoch 4/25
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6259 - accuracy: 0.6463 - precision_1: 0.6463 - recall_1: 0.6463 - val_loss: 0.7317 - val_accuracy: 0.4943 - val_precision_1: 0.4943 - val_recall_1: 0.4943
# Epoch 5/25
# 49/49 [==============================] - 1s 19ms/step - loss: 0.6190 - accuracy: 0.6641 - precision_1: 0.6641 - recall_1: 0.6641 - val_loss: 0.8005 - val_accuracy: 0.5011 - val_precision_1: 0.5011 - val_recall_1: 0.5011
# Epoch 6/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.5680 - accuracy: 0.7127 - precision_1: 0.7127 - recall_1: 0.7127 - val_loss: 0.7209 - val_accuracy: 0.5102 - val_precision_1: 0.5102 - val_recall_1: 0.5102
# Epoch 7/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.4720 - accuracy: 0.7826 - precision_1: 0.7826 - recall_1: 0.7826 - val_loss: 0.8244 - val_accuracy: 0.5208 - val_precision_1: 0.5208 - val_recall_1: 0.5208
# Epoch 8/25
# 49/49 [==============================] - 1s 10ms/step - loss: 0.3261 - accuracy: 0.8620 - precision_1: 0.8620 - recall_1: 0.8620 - val_loss: 1.0780 - val_accuracy: 0.5011 - val_precision_1: 0.5011 - val_recall_1: 0.5011
# Epoch 9/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2920 - accuracy: 0.8873 - precision_1: 0.8873 - recall_1: 0.8873 - val_loss: 1.1506 - val_accuracy: 0.4958 - val_precision_1: 0.4958 - val_recall_1: 0.4958
# Epoch 10/25
# 49/49 [==============================] - 1s 10ms/step - loss: 0.2199 - accuracy: 0.9197 - precision_1: 0.9197 - recall_1: 0.9197 - val_loss: 1.3897 - val_accuracy: 0.5079 - val_precision_1: 0.5079 - val_recall_1: 0.5079
# Epoch 11/25
# 49/49 [==============================] - 1s 12ms/step - loss: 0.1282 - accuracy: 0.9556 - precision_1: 0.9556 - recall_1: 0.9556 - val_loss: 1.6457 - val_accuracy: 0.5026 - val_precision_1: 0.5026 - val_recall_1: 0.5026
# Epoch 12/25
# 49/49 [==============================] - 1s 12ms/step - loss: 0.1059 - accuracy: 0.9644 - precision_1: 0.9644 - recall_1: 0.9644 - val_loss: 1.5098 - val_accuracy: 0.5034 - val_precision_1: 0.5034 - val_recall_1: 0.5034
# Epoch 13/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1217 - accuracy: 0.9527 - precision_1: 0.9527 - recall_1: 0.9527 - val_loss: 1.5974 - val_accuracy: 0.5185 - val_precision_1: 0.5185 - val_recall_1: 0.5185
# Epoch 14/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0651 - accuracy: 0.9825 - precision_1: 0.9825 - recall_1: 0.9825 - val_loss: 1.9159 - val_accuracy: 0.5193 - val_precision_1: 0.5193 - val_recall_1: 0.5193
# Epoch 15/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0267 - accuracy: 0.9932 - precision_1: 0.9932 - recall_1: 0.9932 - val_loss: 2.3065 - val_accuracy: 0.5306 - val_precision_1: 0.5306 - val_recall_1: 0.5306
# Epoch 16/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0394 - accuracy: 0.9913 - precision_1: 0.9913 - recall_1: 0.9913 - val_loss: 2.2481 - val_accuracy: 0.5110 - val_precision_1: 0.5110 - val_recall_1: 0.5110
# Epoch 17/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0171 - accuracy: 0.9971 - precision_1: 0.9971 - recall_1: 0.9971 - val_loss: 2.4753 - val_accuracy: 0.5110 - val_precision_1: 0.5110 - val_recall_1: 0.5110
# Epoch 18/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0086 - accuracy: 0.9987 - precision_1: 0.9987 - recall_1: 0.9987 - val_loss: 2.6536 - val_accuracy: 0.5231 - val_precision_1: 0.5231 - val_recall_1: 0.5231
# Epoch 19/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0048 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 2.7305 - val_accuracy: 0.5231 - val_precision_1: 0.5231 - val_recall_1: 0.5231
# Epoch 20/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0039 - accuracy: 0.9997 - precision_1: 0.9997 - recall_1: 0.9997 - val_loss: 2.9229 - val_accuracy: 0.5246 - val_precision_1: 0.5246 - val_recall_1: 0.5246
# Epoch 21/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0038 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 2.9258 - val_accuracy: 0.5276 - val_precision_1: 0.5276 - val_recall_1: 0.5276
# Epoch 22/25
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0023 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 3.0737 - val_accuracy: 0.5299 - val_precision_1: 0.5299 - val_recall_1: 0.5299
# Epoch 23/25
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0018 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 3.1851 - val_accuracy: 0.5261 - val_precision_1: 0.5261 - val_recall_1: 0.5261
# Epoch 24/25
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0021 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 3.2151 - val_accuracy: 0.5253 - val_precision_1: 0.5253 - val_recall_1: 0.5253
# Epoch 25/25
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0021 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 3.2981 - val_accuracy: 0.5246 - val_precision_1: 0.5246 - val_recall_1: 0.5246
#
# Accuracy  : 0.5164
# Precision : 0.5164
# Recall    : 0.5164
# F1 Score  : 0.5164

# %%
def plot_training_hist(history):
    '''Function to plot history for accuracy and loss'''

    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    # first plot
    ax[0].plot(history.history['accuracy'])
    ax[0].plot(history.history['val_accuracy'])
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('epoch')
    ax[0].set_ylabel('accuracy')
    ax[0].legend(['train', 'validation'], loc='best')
    # second plot
    ax[1].plot(history.history['loss'])
    ax[1].plot(history.history['val_loss'])
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('epoch')
    ax[1].set_ylabel('loss')
    ax[1].legend(['train', 'validation'], loc='best')


plot_training_hist(history)

# %%
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(model, X_test, y_test):
    '''Function to plot confusion matrix for the passed model and the data'''

    sentiment_classes = ['Negative', 'Positive']
    # use model to do the prediction
    y_pred = model.predict(X_test)
    # compute confusion matrix
    cm = confusion_matrix(np.argmax(np.array(y_test), axis=1), np.argmax(y_pred, axis=1))
    # plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='d',
                xticklabels=sentiment_classes,
                yticklabels=sentiment_classes)
    plt.title('Confusion matrix', fontsize=16)
    plt.xlabel('Actual label', fontsize=12)
    plt.ylabel('Predicted label', fontsize=12)


plot_confusion_matrix(model, X_test, y_test)

# Save the model architecture & the weights
model.save('rnn_model.h5')
print('Best model saved')
# Out:
# 60/60 [==============================] - 1s 4ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# Best model saved

# %% [markdown]
# # LSTM

# %%
import keras.backend as K


def f1_score(precision, recall):
    ''' Function to calculate f1 score '''

    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, Dropout,Flatten, LSTM
from keras.metrics import Precision, Recall
from keras.optimizers.legacy import SGD
from keras.optimizers import RMSprop
from keras import datasets

from keras.callbacks import LearningRateScheduler
from keras.callbacks import History

from keras import losses

vocab_size = 5000
embedding_size = 32
epochs=25
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8

sgd = SGD(learning_rate=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
# Build model
model= Sequential()
model.add(Embedding(vocab_size, embedding_size, input_length=max_len))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=4))
model.add(LSTM(12))
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(2, activation='softmax'))
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)
plt.show()
print(model.summary())

# Compile model
model.compile(loss='categorical_crossentropy', optimizer=sgd,
               metrics=['accuracy', Precision(), Recall()])

# Train model

batch_size = 64
history = model.fit(X_train, y_train,
                      validation_data=(X_val, y_val),
                      batch_size=batch_size, epochs=epochs, verbose=1)

# Evaluate model on the test set
loss, lstm_accuracy, precision, recall = model.evaluate(X_test, y_test, verbose=0)
# Print metrics
print('')
print('Accuracy  : {:.4f}'.format(lstm_accuracy))
print('Precision : {:.4f}'.format(precision))
print('Recall    : {:.4f}'.format(recall))
print('F1 Score  : {:.4f}'.format(f1_score(precision, recall)))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 32)            160000
#
#  conv1d_2 (Conv1D)           (None, 50, 32)            3104
#
#  max_pooling1d_2 (MaxPoolin  (None, 12, 32)            0
#  g1D)
#
#  lstm_1 (LSTM)               (None, 12)                2160
#
#  flatten_2 (Flatten)         (None, 12)                0
#
#  dropout_2 (Dropout)         (None, 12)                0
#
#  dense_2 (Dense)             (None, 2)                 26
#
# =================================================================
# Total params: 165290 (645.66 KB)
# Trainable params: 165290 (645.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 49/49 [==============================] - 6s 28ms/step - loss: 0.6918 - accuracy: 0.5274 - precision_2: 0.5274 - recall_2: 0.5274 - val_loss: 0.6908 - val_accuracy: 0.5140 - val_precision_2: 0.5140 - val_recall_2: 0.5140
# Epoch 2/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.6950 - accuracy: 0.5251 - precision_2: 0.5251 - recall_2: 0.5251 - val_loss: 0.6909 - val_accuracy: 0.5193 - val_precision_2: 0.5193 - val_recall_2: 0.5193
# Epoch 3/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.6885 - accuracy: 0.5351 - precision_2: 0.5351 - recall_2: 0.5351 - val_loss: 0.6932 - val_accuracy: 0.5147 - val_precision_2: 0.5147 - val_recall_2: 0.5147
# Epoch 4/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.6879 - accuracy: 0.5371 - precision_2: 0.5371 - recall_2: 0.5371 - val_loss: 0.6891 - val_accuracy: 0.5472 - val_precision_2: 0.5472 - val_recall_2: 0.5472
# Epoch 5/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.6847 - accuracy: 0.5507 - precision_2: 0.5507 - recall_2: 0.5507 - val_loss: 0.6877 - val_accuracy: 0.5238 - val_precision_2: 0.5238 - val_recall_2: 0.5238
# Epoch 6/25
# 49/49 [==============================] - 1s 15ms/step - loss: 0.6826 - accuracy: 0.5750 - precision_2: 0.5750 - recall_2: 0.5750 - val_loss: 0.6860 - val_accuracy: 0.5835 - val_precision_2: 0.5835 - val_recall_2: 0.5835
# Epoch 7/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.6786 - accuracy: 0.5935 - precision_2: 0.5935 - recall_2: 0.5935 - val_loss: 0.6815 - val_accuracy: 0.5994 - val_precision_2: 0.5994 - val_recall_2: 0.5994
# Epoch 8/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.6720 - accuracy: 0.6032 - precision_2: 0.6032 - recall_2: 0.6032 - val_loss: 0.6842 - val_accuracy: 0.5495 - val_precision_2: 0.5495 - val_recall_2: 0.5495
# Epoch 9/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.6591 - accuracy: 0.6187 - precision_2: 0.6187 - recall_2: 0.6187 - val_loss: 0.6583 - val_accuracy: 0.6183 - val_precision_2: 0.6183 - val_recall_2: 0.6183
# Epoch 10/25
# 49/49 [==============================] - 1s 15ms/step - loss: 0.6301 - accuracy: 0.6443 - precision_2: 0.6443 - recall_2: 0.6443 - val_loss: 0.7285 - val_accuracy: 0.5427 - val_precision_2: 0.5427 - val_recall_2: 0.5427
# Epoch 11/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.6053 - accuracy: 0.6774 - precision_2: 0.6774 - recall_2: 0.6774 - val_loss: 0.6585 - val_accuracy: 0.6183 - val_precision_2: 0.6183 - val_recall_2: 0.6183
# Epoch 12/25
# 49/49 [==============================] - 1s 20ms/step - loss: 0.5943 - accuracy: 0.6906 - precision_2: 0.6906 - recall_2: 0.6906 - val_loss: 0.8129 - val_accuracy: 0.5155 - val_precision_2: 0.5155 - val_recall_2: 0.5155
# Epoch 13/25
# 49/49 [==============================] - 2s 39ms/step - loss: 0.5475 - accuracy: 0.7318 - precision_2: 0.7318 - recall_2: 0.7318 - val_loss: 0.5979 - val_accuracy: 0.6780 - val_precision_2: 0.6780 - val_recall_2: 0.6780
# Epoch 14/25
# 49/49 [==============================] - 1s 22ms/step - loss: 0.5285 - accuracy: 0.7480 - precision_2: 0.7480 - recall_2: 0.7480 - val_loss: 0.5627 - val_accuracy: 0.7022 - val_precision_2: 0.7022 - val_recall_2: 0.7022
# Epoch 15/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.4936 - accuracy: 0.7710 - precision_2: 0.7710 - recall_2: 0.7710 - val_loss: 0.5637 - val_accuracy: 0.7120 - val_precision_2: 0.7120 - val_recall_2: 0.7120
# Epoch 16/25
# 49/49 [==============================] - 1s 15ms/step - loss: 0.4615 - accuracy: 0.7937 - precision_2: 0.7937 - recall_2: 0.7937 - val_loss: 0.5370 - val_accuracy: 0.7324 - val_precision_2: 0.7324 - val_recall_2: 0.7324
# Epoch 17/25
# 49/49 [==============================] - 1s 15ms/step - loss: 0.4101 - accuracy: 0.8205 - precision_2: 0.8205 - recall_2: 0.8205 - val_loss: 0.5698 - val_accuracy: 0.7188 - val_precision_2: 0.7188 - val_recall_2: 0.7188
# Epoch 18/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.3889 - accuracy: 0.8361 - precision_2: 0.8361 - recall_2: 0.8361 - val_loss: 0.5242 - val_accuracy: 0.7528 - val_precision_2: 0.7528 - val_recall_2: 0.7528
# Epoch 19/25
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3827 - accuracy: 0.8387 - precision_2: 0.8387 - recall_2: 0.8387 - val_loss: 0.6115 - val_accuracy: 0.7022 - val_precision_2: 0.7022 - val_recall_2: 0.7022
# Epoch 20/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.3279 - accuracy: 0.8727 - precision_2: 0.8727 - recall_2: 0.8727 - val_loss: 0.5601 - val_accuracy: 0.7468 - val_precision_2: 0.7468 - val_recall_2: 0.7468
# Epoch 21/25
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3182 - accuracy: 0.8737 - precision_2: 0.8737 - recall_2: 0.8737 - val_loss: 0.5247 - val_accuracy: 0.7543 - val_precision_2: 0.7543 - val_recall_2: 0.7543
# Epoch 22/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2728 - accuracy: 0.8947 - precision_2: 0.8947 - recall_2: 0.8947 - val_loss: 0.7964 - val_accuracy: 0.6961 - val_precision_2: 0.6961 - val_recall_2: 0.6961
# Epoch 23/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.2857 - accuracy: 0.8850 - precision_2: 0.8850 - recall_2: 0.8850 - val_loss: 0.5384 - val_accuracy: 0.7680 - val_precision_2: 0.7680 - val_recall_2: 0.7680
# Epoch 24/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2265 - accuracy: 0.9167 - precision_2: 0.9167 - recall_2: 0.9167 - val_loss: 0.9051 - val_accuracy: 0.6523 - val_precision_2: 0.6523 - val_recall_2: 0.6523
# Epoch 25/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2447 - accuracy: 0.9031 - precision_2: 0.9031 - recall_2: 0.9031 - val_loss: 0.6123 - val_accuracy: 0.7664 - val_precision_2: 0.7664 - val_recall_2: 0.7664
#
# Accuracy  : 0.7698
# Precision : 0.7698
# Recall    : 0.7698
# F1 Score  : 0.7698

# %%
def plot_training_hist(history):
    '''Function to plot history for accuracy and loss'''

    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    # first plot
    ax[0].plot(history.history['accuracy'])
    ax[0].plot(history.history['val_accuracy'])
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('epoch')
    ax[0].set_ylabel('accuracy')
    ax[0].legend(['train', 'validation'], loc='best')
    # second plot
    ax[1].plot(history.history['loss'])
    ax[1].plot(history.history['val_loss'])
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('epoch')
    ax[1].set_ylabel('loss')
    ax[1].legend(['train', 'validation'], loc='best')


plot_training_hist(history)

# %%
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(model, X_test, y_test):
    '''Function to plot confusion matrix for the passed model and the data'''

    sentiment_classes = ['Negative', 'Positive']
    # use model to do the prediction
    y_pred = model.predict(X_test)
    # compute confusion matrix
    cm = confusion_matrix(np.argmax(np.array(y_test), axis=1), np.argmax(y_pred, axis=1))
    # plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='d',
                xticklabels=sentiment_classes,
                yticklabels=sentiment_classes)
    plt.title('Confusion matrix', fontsize=16)
    plt.xlabel('Actual label', fontsize=12)
    plt.ylabel('Predicted label', fontsize=12)


plot_confusion_matrix(model, X_test, y_test)

# Save the model architecture & the weights
model.save('lstm_model.h5')
print('Best model saved')
# Out:
# 60/60 [==============================] - 1s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# Best model saved

# %% [markdown]
# # CNN

# %%
import keras.backend as K
import tensorflow as tf


def f1_score(precision, recall):
    ''' Function to calculate f1 score '''

    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, Dropout,Flatten, LSTM
from keras.metrics import Precision, Recall
from keras.optimizers.legacy import SGD
from keras.optimizers import RMSprop
from keras import datasets

from keras.callbacks import LearningRateScheduler
from keras.callbacks import History

from keras import losses

vocab_size = 5000
embedding_size = 32
epochs=25
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8

sgd = SGD(learning_rate=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
# Build model
model= Sequential()
model.add(Embedding(vocab_size, embedding_size, input_length=max_len))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=4))
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(2, activation='softmax'))

import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)
plt.show()
print(model.summary())

# Compile model
model.compile(loss='categorical_crossentropy', optimizer=sgd,
               metrics=['accuracy', Precision(), Recall()])

# Train model

batch_size = 64
history = model.fit(X_train, y_train,
                      validation_data=(X_val, y_val),
                      batch_size=batch_size, epochs=epochs, verbose=1)

# Evaluate model on the test set
loss, cnn_accuracy, precision, recall = model.evaluate(X_test, y_test, verbose=0)
# Print metrics
print('')
print('Accuracy  : {:.4f}'.format(cnn_accuracy))
print('Precision : {:.4f}'.format(precision))
print('Recall    : {:.4f}'.format(recall))
print('F1 Score  : {:.4f}'.format(f1_score(precision, recall)))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 50, 32)            160000
#
#  conv1d_3 (Conv1D)           (None, 50, 32)            3104
#
#  max_pooling1d_3 (MaxPoolin  (None, 12, 32)            0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 384)               0
#
#  dropout_3 (Dropout)         (None, 384)               0
#
#  dense_3 (Dense)             (None, 2)                 770
#
# =================================================================
# Total params: 163874 (640.13 KB)
# Trainable params: 163874 (640.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 49/49 [==============================] - 2s 17ms/step - loss: 0.6898 - accuracy: 0.5296 - precision_3: 0.5296 - recall_3: 0.5296 - val_loss: 0.6925 - val_accuracy: 0.5147 - val_precision_3: 0.5147 - val_recall_3: 0.5147
# Epoch 2/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.6838 - accuracy: 0.5504 - precision_3: 0.5504 - recall_3: 0.5504 - val_loss: 0.6890 - val_accuracy: 0.5291 - val_precision_3: 0.5291 - val_recall_3: 0.5291
# Epoch 3/25
# 49/49 [==============================] - 0s 9ms/step - loss: 0.6794 - accuracy: 0.5675 - precision_3: 0.5675 - recall_3: 0.5675 - val_loss: 0.6898 - val_accuracy: 0.5261 - val_precision_3: 0.5261 - val_recall_3: 0.5261
# Epoch 4/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.6749 - accuracy: 0.5756 - precision_3: 0.5756 - recall_3: 0.5756 - val_loss: 0.6841 - val_accuracy: 0.5760 - val_precision_3: 0.5760 - val_recall_3: 0.5760
# Epoch 5/25
# 49/49 [==============================] - 0s 9ms/step - loss: 0.6625 - accuracy: 0.6317 - precision_3: 0.6317 - recall_3: 0.6317 - val_loss: 0.6952 - val_accuracy: 0.5291 - val_precision_3: 0.5291 - val_recall_3: 0.5291
# Epoch 6/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.6558 - accuracy: 0.6271 - precision_3: 0.6271 - recall_3: 0.6271 - val_loss: 0.6786 - val_accuracy: 0.5472 - val_precision_3: 0.5472 - val_recall_3: 0.5472
# Epoch 7/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.6415 - accuracy: 0.6404 - precision_3: 0.6404 - recall_3: 0.6404 - val_loss: 0.6605 - val_accuracy: 0.6039 - val_precision_3: 0.6039 - val_recall_3: 0.6039
# Epoch 8/25
# 49/49 [==============================] - 0s 9ms/step - loss: 0.6181 - accuracy: 0.6644 - precision_3: 0.6644 - recall_3: 0.6644 - val_loss: 0.6493 - val_accuracy: 0.6130 - val_precision_3: 0.6130 - val_recall_3: 0.6130
# Epoch 9/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5947 - accuracy: 0.6897 - precision_3: 0.6897 - recall_3: 0.6897 - val_loss: 0.6424 - val_accuracy: 0.6402 - val_precision_3: 0.6402 - val_recall_3: 0.6402
# Epoch 10/25
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5678 - accuracy: 0.7188 - precision_3: 0.7188 - recall_3: 0.7188 - val_loss: 0.6522 - val_accuracy: 0.6289 - val_precision_3: 0.6289 - val_recall_3: 0.6289
# Epoch 11/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.5514 - accuracy: 0.7311 - precision_3: 0.7311 - recall_3: 0.7311 - val_loss: 0.6310 - val_accuracy: 0.6274 - val_precision_3: 0.6274 - val_recall_3: 0.6274
# Epoch 12/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.5267 - accuracy: 0.7441 - precision_3: 0.7441 - recall_3: 0.7441 - val_loss: 0.5814 - val_accuracy: 0.6961 - val_precision_3: 0.6961 - val_recall_3: 0.6961
# Epoch 13/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.4974 - accuracy: 0.7762 - precision_3: 0.7762 - recall_3: 0.7762 - val_loss: 0.5699 - val_accuracy: 0.7029 - val_precision_3: 0.7029 - val_recall_3: 0.7029
# Epoch 14/25
# 49/49 [==============================] - 1s 14ms/step - loss: 0.4711 - accuracy: 0.7914 - precision_3: 0.7914 - recall_3: 0.7914 - val_loss: 0.5671 - val_accuracy: 0.7067 - val_precision_3: 0.7067 - val_recall_3: 0.7067
# Epoch 15/25
# 49/49 [==============================] - 1s 13ms/step - loss: 0.4488 - accuracy: 0.8073 - precision_3: 0.8073 - recall_3: 0.8073 - val_loss: 0.5380 - val_accuracy: 0.7430 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 16/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.4273 - accuracy: 0.8186 - precision_3: 0.8186 - recall_3: 0.8186 - val_loss: 0.5705 - val_accuracy: 0.6969 - val_precision_3: 0.6969 - val_recall_3: 0.6969
# Epoch 17/25
# 49/49 [==============================] - 0s 9ms/step - loss: 0.4063 - accuracy: 0.8293 - precision_3: 0.8293 - recall_3: 0.8293 - val_loss: 0.5223 - val_accuracy: 0.7528 - val_precision_3: 0.7528 - val_recall_3: 0.7528
# Epoch 18/25
# 49/49 [==============================] - 0s 7ms/step - loss: 0.3934 - accuracy: 0.8348 - precision_3: 0.8348 - recall_3: 0.8348 - val_loss: 0.5233 - val_accuracy: 0.7483 - val_precision_3: 0.7483 - val_recall_3: 0.7483
# Epoch 19/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.3762 - accuracy: 0.8520 - precision_3: 0.8520 - recall_3: 0.8520 - val_loss: 0.5118 - val_accuracy: 0.7536 - val_precision_3: 0.7536 - val_recall_3: 0.7536
# Epoch 20/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.3640 - accuracy: 0.8552 - precision_3: 0.8552 - recall_3: 0.8552 - val_loss: 0.5231 - val_accuracy: 0.7453 - val_precision_3: 0.7453 - val_recall_3: 0.7453
# Epoch 21/25
# 49/49 [==============================] - 0s 7ms/step - loss: 0.3416 - accuracy: 0.8688 - precision_3: 0.8688 - recall_3: 0.8688 - val_loss: 0.5018 - val_accuracy: 0.7619 - val_precision_3: 0.7619 - val_recall_3: 0.7619
# Epoch 22/25
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3168 - accuracy: 0.8834 - precision_3: 0.8834 - recall_3: 0.8834 - val_loss: 0.5062 - val_accuracy: 0.7596 - val_precision_3: 0.7596 - val_recall_3: 0.7596
# Epoch 23/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.3089 - accuracy: 0.8824 - precision_3: 0.8824 - recall_3: 0.8824 - val_loss: 0.5191 - val_accuracy: 0.7483 - val_precision_3: 0.7483 - val_recall_3: 0.7483
# Epoch 24/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.2891 - accuracy: 0.8944 - precision_3: 0.8944 - recall_3: 0.8944 - val_loss: 0.4973 - val_accuracy: 0.7702 - val_precision_3: 0.7702 - val_recall_3: 0.7702
# Epoch 25/25
# 49/49 [==============================] - 0s 8ms/step - loss: 0.2732 - accuracy: 0.9002 - precision_3: 0.9002 - recall_3: 0.9002 - val_loss: 0.5541 - val_accuracy: 0.7339 - val_precision_3: 0.7339 - val_recall_3: 0.7339
#
# Accuracy  : 0.7275
# Precision : 0.7275
# Recall    : 0.7275
# F1 Score  : 0.7275

# %%
def plot_training_hist(history):
    '''Function to plot history for accuracy and loss'''

    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    # first plot
    ax[0].plot(history.history['accuracy'])
    ax[0].plot(history.history['val_accuracy'])
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('epoch')
    ax[0].set_ylabel('accuracy')
    ax[0].legend(['train', 'validation'], loc='best')
    # second plot
    ax[1].plot(history.history['loss'])
    ax[1].plot(history.history['val_loss'])
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('epoch')
    ax[1].set_ylabel('loss')
    ax[1].legend(['train', 'validation'], loc='best')


plot_training_hist(history)

# %%
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(model, X_test, y_test):
    '''Function to plot confusion matrix for the passed model and the data'''

    sentiment_classes = ['Negative', 'Positive']
    # use model to do the prediction
    y_pred = model.predict(X_test)
    # compute confusion matrix
    cm = confusion_matrix(np.argmax(np.array(y_test), axis=1), np.argmax(y_pred, axis=1))
    # plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='d',
                xticklabels=sentiment_classes,
                yticklabels=sentiment_classes)
    plt.title('Confusion matrix', fontsize=16)
    plt.xlabel('Actual label', fontsize=12)
    plt.ylabel('Predicted label', fontsize=12)


plot_confusion_matrix(model, X_test, y_test)

# Save the model architecture & the weights
model.save('cnn_model.h5')
print('Best model saved')
# Out:
# 60/60 [==============================] - 0s 2ms/step
# Best model saved
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.

# %%
acc_level = [bilstm_accuracy,lstm_accuracy,rnn_accuracy,cnn_accuracy]
models = ['BiLSTM','LSTM','RNN','CNN']

scaled_acc_level = [acc * 100 for acc in acc_level]

import seaborn as sns
data = pd.DataFrame({'Model': models[:], 'Accuracy': scaled_acc_level[:]})

plt.figure(figsize=(8, 6))
sns.barplot(x='Model', y='Accuracy', data=data, palette='viridis')
plt.title('Model Accuracy Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy (%)')

# Show the plot
plt.show()
# Out:
# <ipython-input-29-47702d5188c6>:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
